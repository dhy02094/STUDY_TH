# %% [markdown]
# 4

# %%
import pandas as pd

# %%
t = pd.read_csv('https://bit.ly/3HaMAtZ')
t.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  AgeGroup  \
# 0         0       3    male  22.0      1      0   7.2500        S  Age21_30
# 1         1       1  female  38.0      1      0  71.2833        C  Age31_40
# 2         1       3  female  26.0      0      0   7.9250        S  Age21_30
# 3         1       1  female  35.0      1      0  53.1000        S  Age31_40
# 4         0       3    male  35.0      0      0   8.0500        S  Age31_40
#
#    Family  Age_scale1
# 0       2    0.271174
# 1       2    0.472229
# 2       1    0.321438
# 3       2    0.434531
# 4       1    0.434531

# %%
t[(t['Embarked']=='S') & (t['Fare'] >= 100)].sort_values(by='Age')
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch      Fare Embarked  \
# 305         1       1    male   0.92      1      2  151.5500        S
# 297         0       1  female   2.00      1      2  151.5500        S
# 802         1       1    male  11.00      1      2  120.0000        S
# 435         1       1  female  14.00      1      2  120.0000        S
# 689         1       1  female  15.00      0      1  211.3375        S
# 27          0       1    male  19.00      3      2  263.0000        S
# 708         1       1  female  22.00      0      0  151.5500        S
# 88          1       1  female  23.00      3      2  263.0000        S
# 341         1       1  female  24.00      3      2  263.0000        S
# 498         0       1  female  25.00      1      2  151.5500        S
# 730         1       1  female  29.00      0      0  211.3375        S
# 318         1       1  female  31.00      0      2  164.8667        S
# ...

# %%
t[(t['Pclass']==2 & t['Sex'] == 'male')]['Age']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/envs/tf26/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf26/lib/python3.8/site-packages/pandas/core/roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/envs/tf26/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...

# %%
tmp = t.groupby(['Pclass','Sex'])['Age'].mean()
tmp
# Out:
# Pclass  Sex
# 1       female    34.584787
#         male      39.826393
# 2       female    28.540000
#         male      30.876481
# 3       female    22.638958
#         male      27.775216
# Name: Age, dtype: float64

# %%
t.loc[(t['Pclass'] == 2) & (t['Sex']=='male')].mean()
# Out:
# /var/folders/f4/fb3b_sqx3rvc3gfr73v6ck_00000gn/T/ipykernel_2608/3919459031.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   t.loc[(t['Pclass'] == 2) & (t['Sex']=='male')].mean()
# Survived       0.157407
# Pclass         2.000000
# Age           30.876481
# SibSp          0.342593
# Parch          0.222222
# Fare          19.741782
# Family         1.564815
# Age_scale1     0.382715
# dtype: float64

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    object
#  3   Age         891 non-null    float64
#  4   SibSp       891 non-null    int64
#  5   Parch       891 non-null    int64
#  6   Fare        891 non-null    float64
#  7   Embarked    891 non-null    object
#  8   AgeGroup    891 non-null    object
#  9   Family      891 non-null    int64
#  10  Age_scale1  891 non-null    float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 76.7+ KB
