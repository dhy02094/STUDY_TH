# %% [markdown]
# ### Netflix EDA
# - 아래의 서비스에서 데이터를 수집하여 EDA를 수행하세요.
#
#
# - flixpatrol 사이트에서 데이터 수집
#     - `https://flixpatrol.com/top10/netflix/world/2021/full/#netflix-1`
#
#
# - kaggle에서 netflix 컨텐츠 데이터 수집
#     - `https://www.kaggle.com/shivamb/netflix-shows`
#
#
# - 컨텐츠의 등급데이터는 아래의 코드 사용
# ```
# ratings_ages = {'TV-PG': 'Older Kids', 'TV-MA': 'Adults', 'TV-Y7-FV': 'Older Kids',
#                   'TV-Y7': 'Older Kids', 'TV-14': 'Teens', 'R': 'Adults', 'TV-Y': 'Kids',
#                   'NR': 'Adults', 'PG-13': 'Teens', 'TV-G': 'Kids', 'PG': 'Older Kids',
#                   'G': 'Kids', 'UR': 'Adults', 'NC-17': 'Adults'}
# ```

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # MOVIES

# %%
# 1.웹서비스 분석 : url

# %%
url = "https://flixpatrol.com/top10/netflix/world/2021/full"

# %%
# 2.request(url) > response : html

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# > 정상적으로 받았다.

# %%
# 3. html(str) > bs, css-selector > DF

# %%
# bs 객체 만들기
dom = BeautifulSoup(response.text, "html.parser")

# %%
elements = dom.select("#netflix-1 > div.-mx-content > div > div > table > tbody > tr")
len(elements)
# Out:
# 176

# %%
element = elements[0]

# %%
element
# Out:
# <tr class="table-group">
# <td class="table-td w-12 font-semibold text-right text-gray-500 table-hover:text-gray-400">1.</td>
# <td class="table-td w-10">
# <span class="inline-block align-bottom w-6 h-6 rounded-full text-blue-100 bg-blue-600 text-xxs leading-6 text-center">n/a</span>
# </td>
# <td class="table-td">
# <a class="hover:underline" href="/title/red-notice/">Red Notice</a>
# <span class="inline-block align-baseline w-3 h-3" title="This title is Netflix original">
# <svg viewbox="0 0 512 512"><path d="M304 0h96v512h-96zM112 0h96v512h-96z" fill="#b20710"></path><path d="M400 512h-96L112 0h96z" fill="#e50914"></path></svg>
# </span> </td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">25,918</td>
# <td class="table-td w-18 text-right text-gray-500 table-hover:text-gray-400">–</td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">90</td>
# <td class="table-td w-16 text-right text-gray-500 table-hover:text-gray-400">288</td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">48</td>
# <td class="table-td w-16 text-right text-gray-500 table-hover:text-gray-400">540</td>
# <td class="table-td w-12 text-right text-gray-400 font-semibold">25,918</td>
# </tr>

# %% [markdown]
# > 자 여기서 랭크, 제목, (netflix original 인지 아닌지 넣으면 좋을듯) , point, countries, Days

# %%
data = {
    "rank": element.select_one(".table-td").text[:-1],
    "title" : element.select_one(".table-td:nth-child(3)").text.strip(),
    "points" : element.select_one(".table-td:nth-child(4)").text,
    "counries" : element.select_one(".table-td:nth-child(6)").text,
    "days" : element.select_one(".table-td:nth-child(8)").text,
    "isorigianl" : element.select_one(".table-td:nth-child(3) > span")
}
data
# Out:
# {'rank': '152',
#  'title': 'Zero Chill',
#  'points': '1,631',
#  'counries': '49',
#  'days': '20',
#  'isorigianl': <span class="inline-block align-baseline w-3 h-3" title="This title is Netflix original">
#  <svg viewbox="0 0 512 512"><path d="M304 0h96v512h-96zM112 0h96v512h-96z" fill="#b20710"></path><path d="M400 512h-96L112 0h96z" fill="#e50914"></path></svg>
#  </span>}

# %%
datas = []
for element in elements : 
    datas.append({
        "rank": element.select_one(".table-td").text[:-1],
    "title" : element.select_one(".table-td:nth-child(3)").text.strip(),
    "points" : element.select_one(".table-td:nth-child(4)").text,
    "counries" : element.select_one(".table-td:nth-child(6)").text,
    "days" : element.select_one(".table-td:nth-child(8)").text,
    "isoriginal" : element.select_one(".table-td:nth-child(3) > span")
    })
top_movies = pd.DataFrame(datas)
top_movies.tail(3)
# Out:
#     rank           title points counries days isoriginal
# 173  174             Ava    186        4   29       None
# 174  175       Bombshell    181        2   14       None
# 175  176  Man on a Ledge    174        4   13       None

# %% [markdown]
# ## isoriginal 범주형으로 바꾸기

# %%
import numpy as np

# %%
a = np.where(top_movies['isoriginal'].isna(), "No", "YES")
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'No', 'YES', 'YES', 'No', 'YES', 'YES', 'YES',
#        'YES', 'No', 'YES', 'YES', 'YES', 'YES', 'No', 'YES', 'YES', 'YES',
#        'No', 'YES', 'YES', 'No', 'YES', 'YES', 'YES', 'YES', 'No', 'YES',
#        'YES', 'No', 'YES', 'No', 'YES', 'No', 'No', 'YES', 'YES', 'No',
#        'YES', 'YES', 'YES', 'YES', 'No', 'YES', 'YES', 'YES', 'No', 'YES',
#        'YES', 'No', 'YES', 'YES', 'No', 'YES', 'YES', 'No', 'YES', 'YES',
#        'No', 'No', 'YES', 'YES', 'No', 'YES', 'No', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'No', 'YES', 'No', 'No', 'YES', 'YES',
#        'YES', 'No', 'YES', 'No', 'No', 'No', 'YES', 'YES', 'YES', 'YES',
#        'No', 'No', 'YES', 'YES', 'YES', 'YES', 'No', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'No', 'YES', 'YES', 'No', 'YES', 'YES', 'No',
#        'YES', 'YES', 'YES', 'No', 'YES', 'YES', 'YES', 'No', 'YES', 'No',
#        'YES', 'No', 'No', 'YES', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'YES', 'No', 'No', 'YES', 'No', 'No', 'No', 'No', 'No',
#        'No', 'YES', 'No', 'No', 'No', 'YES', 'YES', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'YES', 'No',
#        'No', 'No', 'No', 'No'], dtype='<U3')

# %%
top_movies['isoriginal'] = np.where(top_movies['isoriginal'].isna(), "No", "YES")

# %%
top_movies.head(3)
# Out:
#   rank             title  points counries days isoriginal
# 0    1        Red Notice  25,918       90   48        YES
# 1    2  We Can Be Heroes  25,311       82  214        YES
# 2    3  Army of the Dead  18,888       89   92        YES

# %%
top_movies.tail(3)
# Out:
#     rank           title points counries days isoriginal
# 173  174             Ava    186        4   29         No
# 174  175       Bombshell    181        2   14         No
# 175  176  Man on a Ledge    174        4   13         No

# %%
# 저장하기
top_movies.to_csv("top_movies.csv", index=False)

# %%
pd.read_csv("top_movies.csv")
# Out:
#      rank               title  points  counries  days isoriginal
# 0       1          Red Notice  25,918        90    48        YES
# 1       2    We Can Be Heroes  25,311        82   214        YES
# 2       3    Army of the Dead  18,888        89    92        YES
# 3       4         Wish Dragon  16,953        82    88        YES
# 4       5     Army of Thieves  15,081        90    52        YES
# ..    ...                 ...     ...       ...   ...        ...
# 171   172              Scoob!     202         1    28         No
# 172   173  The Son of Bigfoot     192         7     8         No
# 173   174                 Ava     186         4    29         No
# 174   175           Bombshell     181         2    14         No
# 175   176      Man on a Ledge     174         4    13         No
#
# [176 rows x 6 columns]

# %% [markdown]
# ## DRAMA

# %%
# 1. 웹서비스 분석
url = "https://flixpatrol.com/top10/netflix/world/2021/full"

# %%
# 2.request(url) > response : html
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# 3. html(str) > bs, css-selector > DF
# bs 객체 만들기
dom = BeautifulSoup(response.text, "html.parser")

# %%
elements = dom.select("#netflix-2 > div.-mx-content > div > div > table > tbody > tr")
len(elements)
# Out:
# 152

# %%
datas = []
for element in elements : 
    datas.append({
        "rank": element.select_one(".table-td").text[:-1],
    "title" : element.select_one(".table-td:nth-child(3)").text.strip(),
    "points" : element.select_one(".table-td:nth-child(4)").text,
    "counries" : element.select_one(".table-td:nth-child(6)").text,
    "days" : element.select_one(".table-td:nth-child(8)").text,
    "isoriginal" : element.select_one(".table-td:nth-child(3) > span")
    })
top_drama = pd.DataFrame(datas)
top_drama.head(3)
# Out:
#   rank        title  points counries days          isoriginal
# 0    1   Squid Game  57,980       90  104  [\n, [[], []], \n]
# 1    2  Money Heist  44,382       91  364  [\n, [[], []], \n]
# 2    3        Lupin  42,690       83  256  [\n, [[], []], \n]

# %%
# isoriginal 수정
top_drama['isoriginal'] = np.where(top_drama['isoriginal'].isna(), "No", "YES")
top_drama.head(3)
# Out:
#   rank        title  points counries days isoriginal
# 0    1   Squid Game  57,980       90  104        YES
# 1    2  Money Heist  44,382       91  364        YES
# 2    3        Lupin  42,690       83  256        YES

# %%
# 저장하기 
top_drama.to_csv("top_drama.csv", index=False)

# %%
pd.read_csv("top_drama.csv")
# Out:
#      rank                 title  points  counries  days isoriginal
# 0       1            Squid Game  57,980        90   104        YES
# 1       2           Money Heist  44,382        91   364        YES
# 2       3                 Lupin  42,690        83   256        YES
# 3       4              Sex/Life  34,609        82   141        YES
# 4       5            Bridgerton  33,973        82   146        YES
# ..    ...                   ...     ...       ...   ...        ...
# 147   148                 Fatma   1,680        44    47        YES
# 148   149            Sweet Home   1,656        22    50        YES
# 149   150             Outlander   1,642        22   104         No
# 150   151  Beauty and the Baker   1,638        18    28         No
# 151   152            Zero Chill   1,631        49    20        YES
#
# [152 rows x 6 columns]

# %% [markdown]
# # kaggle 데이터 가져오기

# %%
kag = pd.read_csv("/Users/kimtaehyeong/크롤링프로젝트/netflix_titles.csv")
kag
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
kag['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
kag[kag['title'] == "Fatma"]
# Out:
#     show_id     type  title director  \
# 972    s973  TV Show  Fatma      NaN
#
#                                                   cast country  \
# 972  Burcu Biricik, Uğur Yücel, Mehmet Yılmaz Ak, H...  Turkey
#
#          date_added  release_year rating  duration  \
# 972  April 27, 2021          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 972  International TV Shows, TV Dramas, TV Thrillers
#
#                                            description
# 972  Reeling from tragedy, a nondescript house clea...

# %% [markdown]
# > 방 법 1
# 일단 kag데이터를 순위 데이터에 붙혀서 어떤 유의 관계가 있는지를 설명. 근데 벌써부터 1위인 red notice 가 없어서 짜증남
# 방 법 2
# 수집한 데이터를 분석하는데 isoriginal 비율로 확인(너무 빈약..)
# 방 법 3
# 그냥 데이터 손실이 있더라도 랭크를 타겟으로 잡고 랭크 등급으로 바꿔서 분석을 하자. 그러기 위해선 inner merge가 좋을 듯

# %% [markdown]
# # top_mov + kag data(inner merge)

# %%
# inner merge 해봅시다.
top_kag_mov = pd.merge(top_movies, kag, on='title', how='inner')
top_kag_mov
# Out:
#    rank                           title  points counries days isoriginal  \
# 0     2                We Can Be Heroes  25,311       82  214        YES
# 1     3                Army of the Dead  18,888       89   92        YES
# 2     4                     Wish Dragon  16,953       82   88        YES
# 3     6  The Mitchells vs. The Machines  14,902       82   74        YES
# 4     7                      Fatherhood  14,660       82   54        YES
# ..  ...                             ...     ...      ...  ...        ...
# 84  169                            2012   1,886       31   51         No
# 85  170                          Wanted   1,878       32   20         No
# 86  171                    Just Say Yes   1,878       43   16        YES
# 87  174                             Ava     186        4   29         No
# 88  175                       Bombshell     181        2   14         No
#
#    show_id   type                           director  \
# 0    s1495  Movie                   Robert Rodriguez
# 1     s854  Movie                        Zack Snyder
# 2     s740  Movie                    Chris Appelhans
# 3     s962  Movie             Mike Rianda, Jeff Rowe
# 4     s686  Movie                         Paul Weitz
# ..     ...    ...                                ...
# 84   s1114  Movie                    Roland Emmerich
# 85    s633  Movie                       Nibal Arakji
# 86   s1110  Movie  Appie Boudellah, Aram van de Rest
# 87   s1585  Movie                        Tate Taylor
# 88   s5765  Movie                 Riccardo Pilizzeri
#
#                                                  cast  \
# 0   YaYa Gosselin, Pedro Pascal, Priyanka Chopra, ...
# 1   Dave Bautista, Ella Purnell, Omari Hardwick, G...
# 2   Jimmy Wong, John Cho, Constance Wu, Will Yun L...
# 3   Danny McBride, Abbi Jacobson, Maya Rudolph, Mi...
# 4   Kevin Hart, Alfre Woodard, Lil Rel Howery, DeW...
# ..                                                ...
# 84  John Cusack, Amanda Peet, Chiwetel Ejiofor, Th...
# 85  Daad Rizk, Georges Diab, Sihame Haddad, George...
# 86  Yolanthe Cabau, Noortje Herlaar, Kim-Lian van ...
# 87  Jessica Chastain, Colin Farrell, John Malkovic...
# 88  Ande Cunningham, Mark Mitchinson, Mia Pistoriu...
#
#                          country         date_added  release_year rating  \
# 0                  United States  December 25, 2020          2020     PG
# 1                  United States       May 21, 2021          2021      R
# 2   China, United States, Canada      June 11, 2021          2021     PG
# 3                            NaN     April 30, 2021          2021     PG
# 4                  United States      June 18, 2021          2021  PG-13
# ..                           ...                ...           ...    ...
# 84                 United States      April 1, 2021          2009  PG-13
# 85                           NaN      June 28, 2021          2019  TV-14
# 86                   Netherlands      April 2, 2021          2021  TV-MA
# 87                 United States   December 7, 2020          2020      R
# 88                   New Zealand    October 1, 2016          2016  TV-MA
#
#    duration                                        listed_in  \
# 0   101 min               Children & Family Movies, Comedies
# 1   148 min                Action & Adventure, Horror Movies
# 2   102 min               Children & Family Movies, Comedies
# 3   114 min               Children & Family Movies, Comedies
# 4   111 min                                           Dramas
# ..      ...                                              ...
# 84  158 min             Action & Adventure, Sci-Fi & Fantasy
# 85   90 min                   Comedies, International Movies
# 86   98 min  Comedies, International Movies, Romantic Movies
# 87   97 min                       Action & Adventure, Dramas
# 88   86 min                                           Dramas
#
#                                           description
# 0   When alien invaders capture Earth’s superheroe...
# 1   After a zombie outbreak in Las Vegas, a group ...
# 2   Determined teen Din is longing to reconnect wi...
# 3   A robot apocalypse put the brakes on their cro...
# 4   A widowed new dad copes with doubts, fears, he...
# ..                                                ...
# 84  When a flood of natural disasters begins to de...
# 85  Four seniors embark on misadventures after bre...
# 86  Incurable romantic Lotte finds her life upende...
# 87  An elite assassin wrestling with doubts about ...
# 88  In 1985, when a vessel protesting nuclear test...
#
# [89 rows x 17 columns]

# %% [markdown]
# # 영상 시청 등급이 뭔말인지 모르니 바꿔준다.

# %%
top_kag_mov['rating'] = top_kag_mov['rating'].replace({'TV-PG': 'Older Kids', 'TV-MA': 'Adults', 'TV-Y7-FV': 'Older Kids',
                'TV-Y7': 'Older Kids', 'TV-14': 'Teens', 'R': 'Adults', 'TV-Y': 'Kids',
                'NR': 'Adults', 'PG-13': 'Teens', 'TV-G': 'Kids', 'PG': 'Older Kids',
                'G': 'Kids', 'UR': 'Adults', 'NC-17': 'Adults'})

# %%
top_kag_mov
# Out:
#    rank                           title  points counries days isoriginal  \
# 0     2                We Can Be Heroes  25,311       82  214        YES
# 1     3                Army of the Dead  18,888       89   92        YES
# 2     4                     Wish Dragon  16,953       82   88        YES
# 3     6  The Mitchells vs. The Machines  14,902       82   74        YES
# 4     7                      Fatherhood  14,660       82   54        YES
# ..  ...                             ...     ...      ...  ...        ...
# 84  169                            2012   1,886       31   51         No
# 85  170                          Wanted   1,878       32   20         No
# 86  171                    Just Say Yes   1,878       43   16        YES
# 87  174                             Ava     186        4   29         No
# 88  175                       Bombshell     181        2   14         No
#
#    show_id   type                           director  \
# 0    s1495  Movie                   Robert Rodriguez
# 1     s854  Movie                        Zack Snyder
# 2     s740  Movie                    Chris Appelhans
# 3     s962  Movie             Mike Rianda, Jeff Rowe
# 4     s686  Movie                         Paul Weitz
# ..     ...    ...                                ...
# 84   s1114  Movie                    Roland Emmerich
# 85    s633  Movie                       Nibal Arakji
# 86   s1110  Movie  Appie Boudellah, Aram van de Rest
# 87   s1585  Movie                        Tate Taylor
# 88   s5765  Movie                 Riccardo Pilizzeri
#
#                                                  cast  \
# 0   YaYa Gosselin, Pedro Pascal, Priyanka Chopra, ...
# 1   Dave Bautista, Ella Purnell, Omari Hardwick, G...
# 2   Jimmy Wong, John Cho, Constance Wu, Will Yun L...
# 3   Danny McBride, Abbi Jacobson, Maya Rudolph, Mi...
# 4   Kevin Hart, Alfre Woodard, Lil Rel Howery, DeW...
# ..                                                ...
# 84  John Cusack, Amanda Peet, Chiwetel Ejiofor, Th...
# 85  Daad Rizk, Georges Diab, Sihame Haddad, George...
# 86  Yolanthe Cabau, Noortje Herlaar, Kim-Lian van ...
# 87  Jessica Chastain, Colin Farrell, John Malkovic...
# 88  Ande Cunningham, Mark Mitchinson, Mia Pistoriu...
#
#                          country         date_added  release_year      rating  \
# 0                  United States  December 25, 2020          2020  Older Kids
# 1                  United States       May 21, 2021          2021      Adults
# 2   China, United States, Canada      June 11, 2021          2021  Older Kids
# 3                            NaN     April 30, 2021          2021  Older Kids
# 4                  United States      June 18, 2021          2021       Teens
# ..                           ...                ...           ...         ...
# 84                 United States      April 1, 2021          2009       Teens
# 85                           NaN      June 28, 2021          2019       Teens
# 86                   Netherlands      April 2, 2021          2021      Adults
# 87                 United States   December 7, 2020          2020      Adults
# 88                   New Zealand    October 1, 2016          2016      Adults
#
#    duration                                        listed_in  \
# 0   101 min               Children & Family Movies, Comedies
# 1   148 min                Action & Adventure, Horror Movies
# 2   102 min               Children & Family Movies, Comedies
# 3   114 min               Children & Family Movies, Comedies
# 4   111 min                                           Dramas
# ..      ...                                              ...
# 84  158 min             Action & Adventure, Sci-Fi & Fantasy
# 85   90 min                   Comedies, International Movies
# 86   98 min  Comedies, International Movies, Romantic Movies
# 87   97 min                       Action & Adventure, Dramas
# 88   86 min                                           Dramas
#
#                                           description
# 0   When alien invaders capture Earth’s superheroe...
# 1   After a zombie outbreak in Las Vegas, a group ...
# 2   Determined teen Din is longing to reconnect wi...
# 3   A robot apocalypse put the brakes on their cro...
# 4   A widowed new dad copes with doubts, fears, he...
# ..                                                ...
# 84  When a flood of natural disasters begins to de...
# 85  Four seniors embark on misadventures after bre...
# 86  Incurable romantic Lotte finds her life upende...
# 87  An elite assassin wrestling with doubts about ...
# 88  In 1985, when a vessel protesting nuclear test...
#
# [89 rows x 17 columns]

# %%
# 팀원을 위해 csv 저장해 놓자.
top_kag_mov.to_csv("top_kag_mov.csv")

# %% [markdown]
# # top_dra + kag (inner merge)

# %%
# inner merge 해봅시다.
top_kag_dra = pd.merge(top_drama, kag, on='title', how='inner')
top_kag_dra
# Out:
#     rank                 title  points counries days isoriginal show_id  \
# 0      1            Squid Game  57,980       90  104        YES     s34
# 1      3                 Lupin  42,690       83  256        YES    s735
# 2      4              Sex/Life  34,609       82  141        YES    s639
# 3      5            Bridgerton  33,973       82  146        YES   s1493
# 4      7               Lucifer  32,230       80  212        YES     s83
# ..   ...                   ...     ...      ...  ...        ...     ...
# 96   145          Workin' Moms   1,924       47   18        YES    s545
# 97   147  Crash Landing on You   1,891        9  180        YES   s3130
# 98   148                 Fatma   1,680       44   47        YES    s973
# 99   150             Outlander   1,642       22  104         No   s1378
# 100  152            Zero Chill   1,631       49   20        YES   s1207
#
#         type director                                               cast  \
# 0    TV Show      NaN  Lee Jung-jae, Park Hae-soo, Wi Ha-jun, Oh
# 3    The eight close-knit siblings of the Bridgerto...
# 4    Bored with being the Lord of Hell, the devil r...
# ..                                                 ...
# 96   Maternity leave is over and it's time for thes...
# 97   A paragliding mishap drops a South Korean heir...
# 98   Reeling from tragedy, a nondescript house clea...
# 99   This epic tale adapted from Diana Gabaldon's p...
# 100  Talented teen figure skater Kayla is forced to...
#
# [101 rows x 17 columns]

# %%
# 팀원을 위해 csv 저장해 놓자.
top_kag_dra.to_csv("top_kag_dra.csv")

# %%
top_kag_mov.isnull().sum()
# Out:
# rank             0
# title            0
# points           0
# counries         0
# days             0
# isoriginal       0
# show_id          0
# type             0
# director         1
# cast             1
# country         24
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
kag.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
top_kag_mov_th = top_kag_mov[['rank','title','points','counries','days','isoriginal','rating','duration']]

# %%
top_kag_mov_th
# Out:
#    rank                           title  points counries days isoriginal  \
# 0     2                We Can Be Heroes  25,311       82  214        YES
# 1     3                Army of the Dead  18,888       89   92        YES
# 2     4                     Wish Dragon  16,953       82   88        YES
# 3     6  The Mitchells vs. The Machines  14,902       82   74        YES
# 4     7                      Fatherhood  14,660       82   54        YES
# ..  ...                             ...     ...      ...  ...        ...
# 84  169                            2012   1,886       31   51         No
# 85  170                          Wanted   1,878       32   20         No
# 86  171                    Just Say Yes   1,878       43   16        YES
# 87  174                             Ava     186        4   29         No
# 88  175                       Bombshell     181        2   14         No
#
#         rating duration
# 0   Older Kids  101 min
# 1       Adults  148 min
# 2   Older Kids  102 min
# 3   Older Kids  114 min
# 4        Teens  111 min
# ..         ...      ...
# 84       Teens  158 min
# 85       Teens   90 min
# 86      Adults   98 min
# 87      Adults   97 min
# 88      Adults   86 min
#
# [89 rows x 8 columns]

# %%
bin = [0,20,40,60,80,np.inf]
top_kag_mov_th['rank']
# Out:
# rank          0
# title         0
# points        0
# counries      0
# days          0
# isoriginal    0
# rating        0
# duration      0
# dtype: int64

# %% [markdown]
# # EXAMPLE

# %% [markdown]
# #### EDA의 수행 절차
# - 데이터 수집
# - 결측 데이터의 처리
# - 데이터 탐색
#     - 수집한 데이터에서 자유롭게 주제를 선정하여 데이터 분석을 통한 인사이트 도출
#     - 예시 : 인도영화는 다른 국가보다 러닝타임이 길것이다. 컨텐츠의 퀄리티가 가장 좋은 국가는?

# %% [markdown]
# #### 컨텐츠 타입과 컨텐츠 등급별 컨텐츠의 비율

# %% [markdown]
# # 아래의 코드는 EDA의 예시를 보여주는 것으로 실제 코드가 동작되지 않습니다.
#
# plt.figure(figsize=(20, 5))
#
# plt.subplot(121)
# plt.title("Movie")
# plt.pie(movie_count.values, labels=movie_count.index, autopct="%1.1f%%")
#
# plt.subplot(122)
# plt.title("TV Show")
# plt.pie(tv_count.values, labels=tv_count.index, autopct="%1.1f%%")
#
# plt.show()

# %% [markdown]
# 결론 : 영화가 TV쇼 보다 청소년 관람불가 등급의 비율이 더 높고 TV가 영화보다 청소년관람등급의 컨텐츠의 비율이 더 높습니다.
